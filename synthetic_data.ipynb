# %%
import nltk
import pandas as pd
import random
from typing import List, Mapping, Optional, Sequence

# import gensim
import numpy as np
from numpy.typing import NDArray
from download_hf import download_parquet
from random_text import generate_observation

FloatArray = NDArray[np.float64]

"""
This script was specifically written to prepare the financial_phrasebank dataset
    financial_phrasebank has a single sentence per row
    labels range from 0 (negative), 1(neutral), 2 (positive)
    there are 4 datasets based on % agreement between annotators
"""
import gensim.downloader as api

google_news = api.load("word2vec-google-news-300")
# google_news.save("word2vec-google-news-300.model")
print(google_news)


# import sentiment_economy_news dataset
def import_data(split):
    """
    Import financial_phrasebank dataset
    splits available:
        sentences_50agree,
        sentences_66agree,
        sentences_75agree,
        sentences_allagree
    """
    return download_parquet("financial_phrasebank", split)


def clean_text(text):
    """Clean text."""
    # turn to lowercase
    text = text.lower()
    # split into sentences
    sentences = nltk.sent_tokenize(text)
    # remove punctuation
    sentences = [nltk.word_tokenize(sentence) for _, sentence in enumerate(sentences)]
    sentences = [
        [word for word in sentence if word.isalnum()]
        for _, sentence in enumerate(sentences)
    ]
    sentences = list(filter(None, sentences))
    return sentences


def tokenize_financial_phrasebank(df):
    """
    Tokenize sentiment economy news.
    """
    # tokenize sentences
    df["tokenized_sentences"] = df["sentence"].apply(clean_text)


def sum_token_embeddings(
    token_embeddings: Sequence[FloatArray],
) -> FloatArray:
    """Sum the token embeddings."""
    total: FloatArray = np.array(token_embeddings).sum(axis=0)
    return total


def map_labels(df):
    """Map labels to integers."""
    label_map = {0: -1, 1: 0, 2: 1}
    return df["label"].map(label_map)


def split_train_test(
    X: FloatArray, y: FloatArray, test_percent: float = 20
) -> tuple[FloatArray, FloatArray, FloatArray, FloatArray]:
    """Split data into training and testing sets."""
    N = len(y)
    data_idx = list(range(N))
    random.shuffle(data_idx)
    break_idx = round(test_percent / 100 * N)
    training_idx = data_idx[break_idx:]
    testing_idx = data_idx[:break_idx]
    X_train = X[training_idx, :]
    y_train = y[training_idx]
    X_test = X[testing_idx, :]
    y_test = y[testing_idx]
    return X_train, y_train, X_test, y_test


def generate_data_word2vec(df: pd.DataFrame) -> tuple[FloatArray, FloatArray]:
    """Generate training and testing data with word2vec."""
    # load pre-trained word2vec model
    # google_news = gensim.models.KeyedVectors.load("word2vec-google-news-300.model")
    X: FloatArray = np.array(
        [
            # sum the token embeddings for each sentence. If word is not in the model, return embedding of ['UNK']
            sum_token_embeddings(
                [
                    google_news[word] if word in google_news else google_news["UNK"]
                    for _, word in enumerate(sentence)
                ]
            )
            for _, sentence in enumerate(df.sentence)
        ]
    )
    y: FloatArray = np.array(map_labels(df))
    return split_train_test(X, y)


def etl(split):
    """
    Extract, transform, and load financial_phrasebank
    """
    df = import_data(split)
    tokenize_financial_phrasebank(df)
    X_train, y_train, X_test, y_test = generate_data_word2vec(df)
    return X_train, y_train, X_test, y_test


def aggregate_all_splits():
    """
    Aggregate all splits of financial_phrasebank
    """
    df = pd.DataFrame()
    for split in [
        "sentences_50agree",
        "sentences_66agree",
        "sentences_75agree",
        "sentences_allagree",
    ]:
        df = pd.concat([df, import_data(split)])
    tokenize_financial_phrasebank(df)
    X_train, y_train, X_test, y_test = generate_data_word2vec(df)
    return X_train, y_train, X_test, y_test


def run_experiment() -> None:
    from sklearn.linear_model import LogisticRegression
    from sklearn import metrics

    # prepare training and testing data
    X_train, y_train, X_test, y_test = aggregate_all_splits()

    clf = LogisticRegression(random_state=0, max_iter=1000).fit(X_train, y_train)
    print("word2vec (train):", clf.score(X_train, y_train))
    print("word2vec (test):", clf.score(X_test, y_test))


def send_to_vecs(lst):
    if isinstance(lst, list):
        lst = " ".join(lst[0])
    X: FloatArray = np.array(
        [
            sum_token_embeddings(
                [
                    google_news[word] if word in google_news else google_news["UNK"]
                    for word in lst.split()
                ]
            )
        ]
    )
    return X


nltk.download("gutenberg")
nltk.download("punkt")
corpus = nltk.word_tokenize(nltk.corpus.gutenberg.raw("austen-sense.txt").lower())
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/adlerviton/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adlerviton/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# KeyedVectors<vector_size=300, 3000000 keys>
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/adlerviton/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adlerviton/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

print("training model")
# prepare training and testing data
X_train, y_train, X_test, y_test = aggregate_all_splits()
clf = LogisticRegression(random_state=0, max_iter=1000).fit(X_train, y_train)
# Out:
# training model
# /Users/adlerviton/miniconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
columns = ["text", "vecs", "labels"]
synthetic_df = pd.DataFrame(columns=columns)
for i in range(50):
    rand_text = generate_observation(i, corpus)
    synthetic_df.loc[i] = [rand_text, None, None]  # Add rand_text to synthetic_df

synthetic_df["text"] = synthetic_df["text"].apply(clean_text)
synthetic_df["vecs"] = synthetic_df["text"].apply(send_to_vecs)
print(synthetic_df)
# Out:
#                                                  text  \
# 0   [[lucy, who, had, not, the, smallest, effect, ...
# 1   [[and, the, two, miss, steeles, as, she, had, ...
# 2   [[gracefulness, were, instantly, the, theme, o...
# 3   [[and, the, two, miss, steeles, as, she, had, ...
# 4      [[direct, as, she, had, been, in, the, world]]
# 5   [[night, they, were, to, be, sure, said, elino...
# 6                                     [[back, again]]
# 7   [[a, very, good, and, the, two, miss, steeles,...
# 8   [[have, been, so, happy, and, the, two, miss, ...
# 9   [[size, if, i, had, not, the, smallest, effect...
# 10             [[as, she, had, been, in, the, world]]
# 11  [[my, dear, said, elinor, i, am, sure, i, woul...
# 12  [[her, and, the, two, miss, steeles, as, she, ...
# 13  [[appear, to, advantage, but, i, have, been, s...
# 14  [[at, the, park, and, the, two, miss, steeles,...
# 15  [[urged, the, matter, i, am, sure, i, would, n...
# 16  [[a, very, good, and, the, two, miss, steeles,...
# 17                                       [[offering]]
# 18  [[then, said, elinor, i, am, sure, i, would, n...
# 19  [[therefore, was, to, be, sure, said, elinor, ...
# 20  [[i, am, sure, i, would, not, be, in, town, an...
# 21  [[fondly, observed, may, be, very, glad, to, s...
# 22                                         [[subdue]]
# 23  [[to, be, sure, said, elinor, i, am, sure, i, ...
# 24  [[my, dear, said, elinor, i, am, sure, i, woul...
# 25  [[by, the, entrance, of, the, house, and, the,...
# 26  [[wisest, to, touch, that, point, however, i, ...
# 27  [[sure, i, would, not, be, in, town, and, the,...
# 28  [[supported, by, the, entrance, of, the, house...
# 29  [[imagination, of, her, sister, and, the, two,...
# 30  [[family, and, the, two, miss, steeles, as, sh...
# 31  [[income, and, the, two, miss, steeles, as, sh...
# 32  [[so, much, of, her, sister, and, the, two, mi...
# 33  [[i, am, sure, i, would, not, be, in, town, an...
# 34  [[once, and, the, two, miss, steeles, as, she,...
# 35                             [[almost, every, day]]
# 36                                     [[went, away]]
# 37  [[yourself, and, marianne, i, am, sure, i, wou...
# 38  [[i, am, sure, i, would, not, be, in, town, an...
# 39  [[of, the, house, and, the, two, miss, steeles...
# 40  [[the, same, time, and, the, two, miss, steele...
# 41  [[they, were, to, be, sure, said, elinor, i, a...
# 42  [[with, a, look, of, approbation, inferior, to...
# 43  [[each, other, and, the, two, miss, steeles, a...
# 44                                           [[both]]
# 45  [[satisfied, with, the, most, affectionate, pr...
# 46  [[the, same, time, and, the, two, miss, steele...
# 47  [[know, said, elinor, i, am, sure, i, would, n...
# 48  [[little, or, any, of, their, being, together,...
# 49  [[to, be, sure, said, elinor, i, am, sure, i, ...
#
#                                                  vecs labels
# 0   [[0.1895752, -0.16003418, 0.0105896, 1.3035126...   None
# 1   [[0.10668945, -0.8104248, 0.5211487, 1.5142651...   None
# 2   [[0.6151581, -1.0141144, 0.69311523, 1.8131104...   None
# 3   [[0.10668945, -0.8104248, 0.5211487, 1.5142651...   None
# 4   [[0.10913086, 0.14904785, 0.2267456, 0.2734203...   None
# 5   [[-0.75897217, -0.58833313, 0.47753906, 1.1713...   None
# 6   [[0.1616211, 0.16772461, 0.064697266, 0.384765...   None
# 7   [[0.052978516, -1.3873291, 0.16824341, 1.98521...   None
# 8   [[-0.2781067, -0.9580078, 0.11592865, 1.577253...   None
# 9   [[0.10668945, -0.28405762, 0.5600586, 1.328414...   None
# 10  [[-0.01586914, 0.3687744, 0.20721436, 0.249128...   None
# 11  [[-0.473938, 0.096725464, 1.0512695, 1.7572021...   None
# 12  [[0.25317383, -0.82421875, 0.50198364, 1.47276...   None
# 13  [[-0.4429016, -0.65441895, -0.07297516, 1.8200...   None
# 14  [[0.27905273, -0.9700928, 0.46157837, 1.538923...   None
# 15  [[-0.22998047, -0.011184692, 1.2553711, 1.0955...   None
# 16  [[0.052978516, -1.3873291, 0.16824341, 1.98521...   None
# 17  [[0.0024261475, 0.04638672, -0.103515625, 0.10...   None
# 18  [[-0.58013916, -0.06993103, 0.94677734, 1.3187...   None
# 19  [[-0.89178467, -0.7593689, 0.5678711, 1.271240...   None
# 20  [[-0.56591797, -0.42329407, 0.82614136, 1.3797...   None
# 21  [[0.16333008, -0.38256836, 0.81344604, 2.60302...   None
# 22  [[0.26757812, 0.28515625, 0.07714844, -0.21679...   None
# 23  [[-0.89434814, -0.6583557, 0.7006836, 1.641845...   None
# 24  [[-0.473938, 0.096725464, 1.0512695, 1.7572021...   None
# 25  [[0.24145508, -1.5448608, 0.37472534, 1.975997...   None
# 26  [[-0.13195801, -0.75868225, 0.9724121, 2.18176...   None
# 27  [[-0.099365234, -0.93891907, 0.8210144, 1.8662...   None
# 28  [[-0.09887695, -1.6239624, 0.58322144, 1.93424...   None
# 29  [[0.11352539, -1.8145752, 0.426239, 1.6424389,...   None
# 30  [[0.087890625, -0.92858887, 0.377594, 1.653913...   None
# 31  [[0.30981445, -0.91589355, 0.30825806, 1.53245...   None
# 32  [[0.10668945, -1.7103271, 0.21063232, 1.902771...   None
# 33  [[-0.46044922, -1.0893097, 1.0297546, 2.031128...   None
# 34  [[0.08166504, -0.7772217, 0.5831604, 1.5962963...   None
# 35  [[0.084472656, -0.26757812, 0.13085938, 0.2832...   None
# 36  [[0.14526367, 0.17675781, -0.044189453, 0.0136...   None
# 37  [[-0.26623535, -0.4408722, 0.89697266, 1.81872...   None
# 38  [[-0.56591797, -0.42329407, 0.82614136, 1.3797...   None
# 39  [[0.2331543, -1.4613037, 0.40859985, 1.8713207...   None
# 40  [[0.29418945, -0.70336914, 0.33493042, 1.72910...   None
# 41  [[-1.1047974, -0.6815491, 0.49951172, 1.398193...   None
# 42  [[-0.46972656, -1.4262695, 0.11352539, 2.00732...   None
# 43  [[0.16503906, -1.1693115, 0.38858032, 1.731061...   None
# 44  [[-0.016357422, -0.041015625, -0.08251953, 0.0...   None
# 45  [[0.4282837, -1.2619629, 0.8197937, 2.361084, ...   None
# 46  [[0.29418945, -0.70336914, 0.33493042, 1.72910...   None
# 47  [[-0.67974854, -0.17988586, 0.859375, 1.261596...   None
# 48  [[-0.0024414062, -1.6658936, 0.5397949, 2.7976...   None
# 49  [[-0.89434814, -0.6583557, 0.7006836, 1.641845...   None

# %%
synthetic_df["labels"] = synthetic_df["vecs"].apply(lambda x: clf.predict(x)[0])

Fake_data = synthetic_df[["text", "labels"]]

Fake_data
# Out:
#                                                  text  labels
# 0   [[lucy, who, had, not, the, smallest, effect, ...       0
# 1   [[and, the, two, miss, steeles, as, she, had, ...       0
# 2   [[gracefulness, were, instantly, the, theme, o...       0
# 3   [[and, the, two, miss, steeles, as, she, had, ...       0
# 4      [[direct, as, she, had, been, in, the, world]]       0
# 5   [[night, they, were, to, be, sure, said, elino...       0
# 6                                     [[back, again]]       0
# 7   [[a, very, good, and, the, two, miss, steeles,...       0
# 8   [[have, been, so, happy, and, the, two, miss, ...       0
# 9   [[size, if, i, had, not, the, smallest, effect...       0
# 10             [[as, she, had, been, in, the, world]]       0
# 11  [[my, dear, said, elinor, i, am, sure, i, woul...       0
# 12  [[her, and, the, two, miss, steeles, as, she, ...       0
# 13  [[appear, to, advantage, but, i, have, been, s...       0
# 14  [[at, the, park, and, the, two, miss, steeles,...       0
# 15  [[urged, the, matter, i, am, sure, i, would, n...       0
# 16  [[a, very, good, and, the, two, miss, steeles,...       0
# 17                                       [[offering]]       0
# 18  [[then, said, elinor, i, am, sure, i, would, n...       0
# 19  [[therefore, was, to, be, sure, said, elinor, ...       0
# 20  [[i, am, sure, i, would, not, be, in, town, an...       0
# 21  [[fondly, observed, may, be, very, glad, to, s...       0
# 22                                         [[subdue]]       0
# 23  [[to, be, sure, said, elinor, i, am, sure, i, ...       0
# 24  [[my, dear, said, elinor, i, am, sure, i, woul...       0
# 25  [[by, the, entrance, of, the, house, and, the,...       0
# 26  [[wisest, to, touch, that, point, however, i, ...       0
# 27  [[sure, i, would, not, be, in, town, and, the,...       0
# 28  [[supported, by, the, entrance, of, the, house...       0
# 29  [[imagination, of, her, sister, and, the, two,...       0
# 30  [[family, and, the, two, miss, steeles, as, sh...       0
# 31  [[income, and, the, two, miss, steeles, as, sh...       0
# 32  [[so, much, of, her, sister, and, the, two, mi...       0
# 33  [[i, am, sure, i, would, not, be, in, town, an...       0
# 34  [[once, and, the, two, miss, steeles, as, she,...       0
# 35                             [[almost, every, day]]       0
# 36                                     [[went, away]]       0
# 37  [[yourself, and, marianne, i, am, sure, i, wou...       0
# 38  [[i, am, sure, i, would, not, be, in, town, an...       0
# 39  [[of, the, house, and, the, two, miss, steeles...       0
# 40  [[the, same, time, and, the, two, miss, steele...       0
# 41  [[they, were, to, be, sure, said, elinor, i, a...       0
# 42  [[with, a, look, of, approbation, inferior, to...       0
# 43  [[each, other, and, the, two, miss, steeles, a...       0
# 44                                           [[both]]       0
# 45  [[satisfied, with, the, most, affectionate, pr...       0
# 46  [[the, same, time, and, the, two, miss, steele...       0
# 47  [[know, said, elinor, i, am, sure, i, would, n...       0
# 48  [[little, or, any, of, their, being, together,...       0
# 49  [[to, be, sure, said, elinor, i, am, sure, i, ...       0
